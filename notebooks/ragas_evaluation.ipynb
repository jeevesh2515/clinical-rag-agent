# %% [markdown]
# # RAGAS Evaluation
#
# Run the clinical RAG evaluation harness and inspect faithfulness, answer relevancy, context precision, and context recall.

# %%
from pathlib import Path
from app.evaluation.run import run_evaluation

results = run_evaluation(Path('../data/eval/golden_questions.jsonl'), Path('../data/eval/results.json'))
results['scores']
